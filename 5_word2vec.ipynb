# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  # Consider only top 50000 words.
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)  # Assigning word id.
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK'] UNK = unknown.
      unk_count = unk_count + 1
    data.append(index)  # data: transferred text as a list of word ids.
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5237, 3081, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)  # Just for edge management.
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
    print(batch, labels)
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'originated', 'a', 'term', 'as', 'a', 'of']
# [3081 3081   12   12    6    6  195  195] [[  12]
#  [5237]
#  [3081]
#  [   6]
#  [ 195]
#  [  12]
#  [   6]
#  [   2]]
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'anarchism', 'term', 'originated', 'of', 'term', 'as']
# [12 12 12 12  6  6  6  6] [[   6]
#  [3081]
#  [5237]
#  [ 195]
#  [3081]
#  [   2]
#  [ 195]
#  [  12]]

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  print(embed)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# Tensor("embedding_lookup:0", shape=(128, 128), dtype=float32, device=/device:CPU:0)

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.921964
# Nearest to called: floppy, says, deoxyribose, powerfully, gutenberg, xenophon, nail, emmy,
# Nearest to was: inexplicable, conform, sailor, condita, symptoms, chroma, manifestation, stored,
# Nearest to have: predicting, courtship, conditional, platters, sobib, curlers, hangings, carom,
# Nearest to such: overwrite, mediawiki, discontinue, purpurea, tokyo, discord, zoroastrian, diaphragm,
# Nearest to between: passed, technicians, slum, unaccustomed, eszterh, antrim, lutes, hermeneutic,
# Nearest to to: medication, facilitated, interquartile, nawab, cultures, bitumen, rearward, conjectural,
# Nearest to up: doe, outta, barter, feminist, apuleius, adjoined, osiris, theoretical,
# Nearest to and: funimation, waite, mitford, swelling, talib, ifad, disadvantaged, channel,
# Nearest to state: virgil, acr, carangi, pierce, undirected, oligopoly, heschel, champion,
# Nearest to from: arc, tout, wallenberg, forgiveness, batsman, colleague, disability, heuristics,
# Nearest to while: acutely, inquiry, bleaching, vol, alois, barbosa, pharmacology, aren,
# Nearest to b: mondial, hesitated, individualist, redactor, clashing, darrell, thelema, midrash,
# Nearest to some: ambiguities, hideous, ted, fairchild, professionals, ancestral, cycles, attack,
# Nearest to use: willfully, genscher, mindanao, shear, connoisseurs, lists, problems, agrarianism,
# Nearest to are: lightly, folie, suggestions, bouts, jorkens, ashmore, manifestations, irix,
# Nearest to often: hain, etext, tables, wrongly, holocene, dropped, errand, whispers,
# Average loss at step 2000: 4.366939
# Average loss at step 4000: 3.862344
# Average loss at step 6000: 3.789151
# Average loss at step 8000: 3.683897
# Average loss at step 10000: 3.616075
# Nearest to called: floppy, deoxyribose, says, treated, superconductor, nail, statistics, sachsen,
# Nearest to was: is, were, has, had, by, became, are, been,
# Nearest to have: had, has, be, were, carcinoma, are, samhain, prior,
# Nearest to such: mediawiki, overwrite, known, purpurea, discontinue, jehoshaphat, implies, durant,
# Nearest to between: with, unbaptized, while, tesco, cessation, throughout, passed, feedback,
# Nearest to to: emily, facilitated, interquartile, cultures, would, not, charlotte, clp,
# Nearest to up: outta, feminist, barter, doe, osiris, iis, sharpened, newline,
# Nearest to and: or, who, lingo, he, on, guerillas, deterred, styria,
# Nearest to state: virgil, undirected, language, translate, ec, rufus, pierce, auger,
# Nearest to from: in, into, fellow, epithet, incompletely, by, xe, kindly,
# Nearest to while: acutely, amhara, between, alois, when, charts, pharmacology, appropriated,
# Nearest to b: d, mondial, popov, eurocents, hesitated, shlomo, and, mcgowan,
# Nearest to some: many, professionals, this, cycles, mesozoic, tactile, shortwave, other,
# Nearest to use: connoisseurs, lists, embraced, problems, howitzers, dalmatian, agrarianism, weakest,
# Nearest to are: were, is, include, have, was, be, laotian, revivals,
# Nearest to often: who, not, errand, wrongly, hain, ellsworth, inventive, also,
# Average loss at step 12000: 3.605490
# Average loss at step 14000: 3.571614
# Average loss at step 16000: 3.410712
# Average loss at step 18000: 3.457293
# Average loss at step 20000: 3.541199
# Nearest to called: floppy, deoxyribose, treated, craters, tenants, says, superconductor, statistics,
# Nearest to was: is, were, has, became, had, been, be, did,
# Nearest to have: had, has, be, were, are, having, take, carcinoma,
# Nearest to such: known, these, well, overwrite, notches, discontinue, purpurea, mediawiki,
# Nearest to between: with, against, tesco, unbaptized, chemically, carrie, tails, while,
# Nearest to to: can, not, would, jets, will, interquartile, could, must,
# Nearest to up: him, feminist, shy, sharpened, doe, teatro, esters, emily,
# Nearest to and: or, but, from, in, which, byzantine, iles, for,
# Nearest to state: virgil, translate, bysshe, undirected, auger, dacko, poisoning, cryptographer,
# Nearest to from: into, in, and, incompletely, against, curative, fellow, severance,
# Nearest to while: when, acutely, kimchi, appropriated, parthia, s, between, jamming,
# Nearest to b: d, popov, ricky, valyria, mcgowan, eurocents, clearinghouse, extinctions,
# Nearest to some: many, all, other, these, professionals, this, any, their,
# Nearest to use: most, howitzers, lists, dalmatian, map, embraced, connoisseurs, problems,
# Nearest to are: were, is, have, include, cassidy, script, other, perez,
# Nearest to often: who, also, errand, sometimes, widely, which, not, curtiss,
# Average loss at step 22000: 3.502270
# Average loss at step 24000: 3.487000
# Average loss at step 26000: 3.482215
# Average loss at step 28000: 3.481634
# Average loss at step 30000: 3.497830
# Nearest to called: tenants, floppy, craters, deoxyribose, treated, fouled, rockstar, ancients,
# Nearest to was: is, had, were, became, has, been, when, by,
# Nearest to have: had, has, were, are, be, begin, having, include,
# Nearest to such: well, these, known, notches, overwrite, many, defined, durant,
# Nearest to between: with, against, chemically, tesco, tarn, carrie, throughout, cronus,
# Nearest to to: would, interquartile, will, not, can, bowman, zenith, must,
# Nearest to up: him, down, out, back, esters, evanston, teatro, shy,
# Nearest to and: or, but, in, superclass, anglican, where, sample, among,
# Nearest to state: virgil, dewitt, heschel, retaliated, translate, mcconnell, bysshe, coney,
# Nearest to from: into, of, under, in, within, faunas, shropshire, heuristics,
# Nearest to while: when, acutely, although, jamming, but, nga, charts, jah,
# Nearest to b: d, popov, hartman, swedish, clearinghouse, eurocents, subsided, bacillus,
# Nearest to some: many, these, all, several, their, any, most, this,
# Nearest to use: mouth, most, lists, substitutes, problems, connoisseurs, method, kadyrov,
# Nearest to are: were, include, have, is, these, cassidy, be, other,
# Nearest to often: sometimes, also, who, widely, still, not, usually, commonly,
# Average loss at step 32000: 3.501697
# Average loss at step 34000: 3.491020
# Average loss at step 36000: 3.453215
# Average loss at step 38000: 3.296348
# Average loss at step 40000: 3.424145
# Nearest to called: tenants, treated, minuscule, rockstar, floppy, named, nagel, craters,
# Nearest to was: is, became, has, were, had, been, be, being,
# Nearest to have: had, has, were, be, are, begin, traditionally, take,
# Nearest to such: known, well, these, defined, described, notches, overwrite, specific,
# Nearest to between: with, against, throughout, tarn, carrie, among, chemically, parlay,
# Nearest to to: can, could, would, must, will, should, interquartile, may,
# Nearest to up: him, out, down, them, back, penrose, off, shy,
# Nearest to and: or, but, including, southerner, aldrich, while, in, where,
# Nearest to state: dewitt, coney, heller, british, auger, virgil, bysshe, carriage,
# Nearest to from: into, alegre, peritoneum, of, through, between, on, in,
# Nearest to while: when, although, acutely, where, but, however, after, are,
# Nearest to b: d, UNK, tu, c, r, f, graviton, e,
# Nearest to some: many, these, any, their, several, this, both, all,
# Nearest to use: need, kadyrov, kaufman, rise, zadok, mouth, most, substitutes,
# Nearest to are: were, is, have, include, mahabharata, but, including, be,
# Nearest to often: usually, also, who, sometimes, widely, which, still, commonly,
# Average loss at step 42000: 3.436864
# Average loss at step 44000: 3.452093
# Average loss at step 46000: 3.454144
# Average loss at step 48000: 3.351807
# Average loss at step 50000: 3.385924
# Nearest to called: tenants, named, treated, known, des, luxuries, minuscule, sentience,
# Nearest to was: is, became, were, has, had, been, be, being,
# Nearest to have: had, has, were, be, are, begin, having, include,
# Nearest to such: these, known, well, many, defined, described, cow, specific,
# Nearest to between: with, against, among, throughout, chemically, parlay, madhuri, factually,
# Nearest to to: can, would, must, could, should, interquartile, may, facilitated,
# Nearest to up: out, down, off, him, them, back, penrose, teatro,
# Nearest to and: or, but, including, of, saxon, ineffectual, administrative, in,
# Nearest to state: dewitt, coney, ec, merina, resort, cryptographer, bysshe, bcs,
# Nearest to from: through, into, in, during, within, until, heuristics, since,
# Nearest to while: when, although, however, where, but, after, acutely, redefinition,
# Nearest to b: d, f, r, clearinghouse, unsettling, tu, lt, bacillus,
# Nearest to some: many, several, these, both, their, the, other, those,
# Nearest to use: mouth, kadyrov, rise, method, need, usage, most, end,
# Nearest to are: were, is, have, include, haredi, be, flavius, those,
# Nearest to often: sometimes, usually, widely, commonly, generally, also, frequently, who,
# Average loss at step 52000: 3.438147
# Average loss at step 54000: 3.425020
# Average loss at step 56000: 3.436227
# Average loss at step 58000: 3.394185
# Average loss at step 60000: 3.393891
# Nearest to called: used, tenants, named, known, found, treated, minuscule, craters,
# Nearest to was: became, is, had, were, has, be, when, ricci,
# Nearest to have: has, had, are, were, provide, be, include, want,
# Nearest to such: known, these, many, well, specific, certain, described, defined,
# Nearest to between: with, against, among, chemically, parlay, scotus, throughout, madhuri,
# Nearest to to: interquartile, kib, not, would, zenith, may, must, for,
# Nearest to up: down, out, off, him, them, back, penrose, teatro,
# Nearest to and: or, but, including, gz, jamming, lasting, than, in,
# Nearest to state: dewitt, coney, government, kind, appropriated, honorius, cryptographer, beam,
# Nearest to from: into, through, within, in, since, jaeger, heuristics, peritoneum,
# Nearest to while: although, when, after, including, iquique, bertolt, where, during,
# Nearest to b: d, f, p, r, c, lt, transforming, clearinghouse,
# Nearest to some: many, several, these, all, any, this, another, both,
# Nearest to use: mouth, most, need, rise, assumption, usage, know, substitutes,
# Nearest to are: were, is, have, include, contends, these, be, gainesville,
# Nearest to often: sometimes, usually, commonly, generally, widely, frequently, also, still,
# Average loss at step 62000: 3.232849
# Average loss at step 64000: 3.256768
# Average loss at step 66000: 3.405475
# Average loss at step 68000: 3.394033
# Average loss at step 70000: 3.355682
# Nearest to called: named, tenants, known, used, referred, sahrawi, minuscule, found,
# Nearest to was: is, has, had, were, became, been, when, be,
# Nearest to have: had, has, were, are, be, require, include, provide,
# Nearest to such: these, known, well, many, specific, defined, certain, including,
# Nearest to between: with, among, against, within, parlay, from, in, around,
# Nearest to to: can, would, will, must, could, should, may, might,
# Nearest to up: off, down, them, back, out, him, straight, penrose,
# Nearest to and: or, while, but, which, including, jamming, circumcise, than,
# Nearest to state: government, dewitt, city, beam, coney, sld, neologism, abugidas,
# Nearest to from: through, into, within, between, incompletely, in, toward, believing,
# Nearest to while: although, when, where, including, after, and, however, are,
# Nearest to b: d, r, f, p, transforming, tu, rude, mcgowan,
# Nearest to some: many, several, all, these, both, any, various, most,
# Nearest to use: mouth, need, most, usage, assumption, because, rise, sow,
# Nearest to are: were, include, is, have, including, although, while, these,
# Nearest to often: usually, sometimes, commonly, generally, frequently, widely, still, typically,
# Average loss at step 72000: 3.368794
# Average loss at step 74000: 3.348250
# Average loss at step 76000: 3.315559
# Average loss at step 78000: 3.351328
# Average loss at step 80000: 3.374636
# Nearest to called: used, known, named, referred, minuscule, tenants, considered, yorktown,
# Nearest to was: is, were, had, has, became, been, when, although,
# Nearest to have: had, has, were, are, be, having, include, tend,
# Nearest to such: these, well, known, specific, certain, described, defined, many,
# Nearest to between: among, within, with, around, against, factually, from, parlay,
# Nearest to to: should, interquartile, anytime, cannot, bowman, will, foal, would,
# Nearest to up: off, out, down, them, him, back, straight, mauritian,
# Nearest to and: or, including, but, while, cleartype, jj, kilometers, futurist,
# Nearest to state: city, government, coney, abugidas, dewitt, honorius, kind, presidents,
# Nearest to from: into, through, within, in, between, faunas, heuristics, on,
# Nearest to while: although, when, however, after, though, before, but, or,
# Nearest to b: d, r, transforming, f, salomon, tu, bacillus, unsettling,
# Nearest to some: many, several, most, various, certain, both, any, all,
# Nearest to use: because, remove, colitis, mouth, need, most, builds, geralt,
# Nearest to are: were, include, have, is, although, including, esr, flavius,
# Nearest to often: usually, sometimes, commonly, generally, typically, frequently, still, widely,
# Average loss at step 82000: 3.404071
# Average loss at step 84000: 3.410606
# Average loss at step 86000: 3.387189
# Average loss at step 88000: 3.355431
# Average loss at step 90000: 3.365101
# Nearest to called: used, named, known, referred, tenants, considered, oust, minuscule,
# Nearest to was: is, had, became, were, has, been, be, began,
# Nearest to have: had, has, were, are, be, having, tend, include,
# Nearest to such: known, well, these, certain, described, follows, specific, many,
# Nearest to between: with, within, among, around, through, against, truncation, over,
# Nearest to to: interquartile, would, will, writ, must, shy, zenith, towards,
# Nearest to up: off, out, down, back, him, them, straight, teatro,
# Nearest to and: or, but, including, viscous, gabriele, in, while, breisgau,
# Nearest to state: city, government, merina, abugidas, beam, mondays, coney, appropriated,
# Nearest to from: into, through, within, during, heuristics, between, before, prostaglandins,
# Nearest to while: although, when, after, though, during, before, however, where,
# Nearest to b: d, r, tu, transforming, bacillus, mckee, rolf, salomon,
# Nearest to some: many, several, these, any, both, certain, most, those,
# Nearest to use: usage, because, most, colitis, remove, geralt, need, sense,
# Nearest to are: were, include, is, have, these, those, contain, including,
# Nearest to often: usually, sometimes, commonly, generally, typically, frequently, also, widely,
# Average loss at step 92000: 3.400811
# Average loss at step 94000: 3.247706
# Average loss at step 96000: 3.354961
# Average loss at step 98000: 3.240869
# Average loss at step 100000: 3.356648
# Nearest to called: named, used, referred, known, tenants, minuscule, oust, there,
# Nearest to was: is, became, were, has, had, been, shortened, pio,
# Nearest to have: had, has, tend, were, are, include, provide, be,
# Nearest to such: known, well, these, tiki, many, defined, certain, specific,
# Nearest to between: with, among, within, through, against, chemically, around, factually,
# Nearest to to: must, will, could, would, should, can, interquartile, cannot,
# Nearest to up: off, out, back, down, him, them, straight, teatro,
# Nearest to and: or, but, while, although, like, however, millard, including,
# Nearest to state: city, beam, government, abugidas, press, virtues, coney, kind,
# Nearest to from: into, through, within, during, in, drexler, rajput, incompletely,
# Nearest to while: although, when, though, and, however, but, after, before,
# Nearest to b: d, clearinghouse, schwa, ounces, swedish, stadia, r, dam,
# Nearest to some: many, several, these, any, certain, all, their, those,
# Nearest to use: because, most, usage, colitis, sense, remove, hear, need,
# Nearest to are: were, have, include, be, including, flavius, contain, these,
# Nearest to often: usually, sometimes, generally, commonly, typically, frequently, widely, still,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch_cbow(batch_size, window):
  global data_index
  batch = []
  labels = []

  for i in range(batch_size):
    labels.append(data[data_index + window + i])
    batch_element = []
    for j in range(window):
      batch_element.append(data[data_index + window + i - j - 1])
      batch_element.append(data[data_index + window + i + j + 1])
    batch.append(batch_element)
  return np.array(batch, dtype=np.int32), np.array(labels, dtype=np.int32).reshape(batch_size, 1)

print('data:', [reverse_dictionary[di] for di in data[:8]])

for window in [2, 5]:
    data_index = 0
    batch, labels = generate_batch_cbow(batch_size=8, window=window)
    print('\nwith window = %d:' % (window))
    print('    batch:', [','.join([reverse_dictionary[i] for i in bi]) for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
    print(batch, labels)
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with window = 2:
#     batch: ['originated,a,anarchism,term', 'as,term,originated,of', 'a,of,as,abuse', 'term,abuse,a,first', 'of,first,term,used', 'abuse,used,of,against', 'first,against,abuse,early', 'used,early,first,working']
#     labels: ['as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against']
# [[3081    6 5237  195]
#  [  12  195 3081    2]
#  [   6    2   12 3135]
#  [ 195 3135    6   46]
#  [   2   46  195   59]
#  [3135   59    2  156]
#  [  46  156 3135  128]
#  [  59  128   46  742]] [[  12]
#  [   6]
#  [ 195]
#  [   2]
#  [3135]
#  [  46]
#  [  59]
#  [ 156]]
#
# with window = 5:
#     batch: ['term,abuse,a,first,as,used,originated,against,anarchism,early', 'of,first,term,used,a,against,as,early,originated,working', 'abuse,used,of,against,term,early,a,working,as,class', 'first,against,abuse,early,of,working,term,class,a,radicals', 'used,early,first,working,abuse,class,of,radicals,term,including', 'against,working,used,class,first,radicals,abuse,including,of,the', 'early,class,against,radicals,used,including,first,the,abuse,diggers', 'working,radicals,early,including,against,the,used,diggers,first,of']
#     labels: ['of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class']
# [[  195  3135     6    46    12    59  3081   156  5237   128]
#  [    2    46   195    59     6   156    12   128  3081   742]
#  [ 3135    59     2   156   195   128     6   742    12   477]
#  [   46   156  3135   128     2   742   195   477     6 10600]
#  [   59   128    46   742  3135   477     2 10600   195   134]
#  [  156   742    59   477    46 10600  3135   134     2     1]
#  [  128   477   156 10600    59   134    46     1  3135 27826]
#  [  742 10600   128   134   156     1    59 27826    46     2]] [[   2]
#  [3135]
#  [  46]
#  [  59]
#  [ 156]
#  [ 128]
#  [ 742]
#  [ 477]]

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
window = 2 # How many words to consider left and right.
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.reduce_sum(tf.nn.embedding_lookup(embeddings, train_dataset), [1])
    
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch_cbow(
      batch_size, window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 8.197861
# Nearest to have: motorways, phys, rshavn, critically, moto, wenceslaus, oxford, theatrical,
# Nearest to not: cia, plagioclase, cadres, summarizes, psychical, sadly, understood, explain,
# Nearest to can: montju, limewire, demonstrating, luz, uu, carla, whitespace, asmara,
# Nearest to state: pluto, ack, washington, lymphatic, starships, windsor, morava, avicenna,
# Nearest to that: rovers, samoa, veritas, fewest, outbreaks, messier, recanted, rival,
# Nearest to six: daoud, password, kosova, kinky, pollutant, chrismation, livonian, brutality,
# Nearest to more: startup, quiet, high, manfred, withdraws, zanu, deum, succeed,
# Nearest to the: triphosphate, gator, closures, mcluhan, proof, wilbur, galatia, diametrically,
# Nearest to to: clerical, burdensome, reuss, multilateral, supervisory, deer, dod, mats,
# Nearest to three: bessarabia, decca, food, chorus, silky, alkoxide, geometry, ir,
# Nearest to would: dan, sicilian, constituci, succeed, backgammon, helmut, emitter, xyz,
# Nearest to use: lasorda, promise, inquest, wicket, thebes, motif, coherence, letterbox,
# Nearest to over: blythe, simulation, astrobiology, private, breathes, steak, psc, location,
# Nearest to some: permutation, calhoun, rebuilding, polymorphic, rakyat, jehovah, flybys, fest,
# Nearest to called: adorned, compactly, pb, dozens, mime, lothal, reconciliation, intercommunal,
# Nearest to all: empiricism, rutland, printed, aspectual, waste, expiration, visibility, ratios,
# Average loss at step 2000: 0.003110
# Average loss at step 4000: 0.000126
# Average loss at step 6000: 0.000074
# Average loss at step 8000: 0.000054
# Average loss at step 10000: 0.000043
# Nearest to have: motorways, phys, rshavn, critically, moto, wenceslaus, oxford, theatrical,
# Nearest to not: cia, plagioclase, cadres, summarizes, sadly, psychical, understood, explain,
# Nearest to can: montju, limewire, demonstrating, luz, uu, carla, whitespace, asmara,
# Nearest to state: pluto, ack, slobodan, lymphatic, washington, privately, theodora, starships,
# Nearest to that: rovers, samoa, fewest, veritas, outbreaks, messier, recanted, cliffs,
# Nearest to six: daoud, password, kosova, kinky, pollutant, chrismation, livonian, brutality,
# Nearest to more: startup, quiet, high, manfred, withdraws, zanu, deum, succeed,
# Nearest to the: triphosphate, gator, closures, mcluhan, proof, galatia, wilbur, diametrically,
# Nearest to to: clerical, burdensome, reuss, supervisory, multilateral, deer, dod, mats,
# Nearest to three: bessarabia, decca, food, chorus, silky, alkoxide, geometry, ir,
# Nearest to would: dan, sicilian, constituci, succeed, backgammon, helmut, emitter, xyz,
# Nearest to use: lasorda, promise, inquest, wicket, thebes, motif, electrical, coherence,
# Nearest to over: blythe, simulation, astrobiology, private, breathes, steak, psc, location,
# Nearest to some: permutation, calhoun, rebuilding, polymorphic, rakyat, jehovah, flybys, fest,
# Nearest to called: adorned, compactly, pb, dozens, mime, lothal, reconciliation, intercommunal,
# Nearest to all: empiricism, rutland, printed, aspectual, waste, expiration, visibility, ratios,
# Average loss at step 12000: 0.000035
# Average loss at step 14000: 0.000030
# Average loss at step 16000: 0.000027
# Average loss at step 18000: 0.000024
# Average loss at step 20000: 0.000021
# Nearest to have: motorways, phys, rshavn, critically, moto, wenceslaus, oxford, theatrical,
# Nearest to not: cia, plagioclase, cadres, summarizes, sadly, psychical, understood, explain,
# Nearest to can: montju, limewire, demonstrating, luz, uu, carla, whitespace, asmara,
# Nearest to state: pluto, ack, slobodan, lymphatic, privately, washington, theodora, starships,
# Nearest to that: rovers, samoa, fewest, veritas, outbreaks, messier, recanted, cliffs,
# Nearest to six: daoud, password, kosova, kinky, pollutant, chrismation, livonian, brutality,
# Nearest to more: startup, quiet, high, manfred, withdraws, zanu, deum, succeed,
# Nearest to the: triphosphate, gator, closures, mcluhan, proof, galatia, wilbur, instructors,
# Nearest to to: clerical, burdensome, reuss, supervisory, multilateral, deer, dod, mats,
# Nearest to three: bessarabia, decca, food, chorus, silky, alkoxide, geometry, ir,
# Nearest to would: dan, sicilian, constituci, succeed, backgammon, helmut, emitter, xyz,
# Nearest to use: lasorda, promise, inquest, wicket, thebes, motif, electrical, coherence,
# Nearest to over: blythe, simulation, astrobiology, private, breathes, steak, psc, location,
# Nearest to some: permutation, calhoun, rebuilding, polymorphic, rakyat, jehovah, flybys, fest,
# Nearest to called: adorned, compactly, pb, dozens, mime, lothal, reconciliation, intercommunal,
# Nearest to all: empiricism, rutland, printed, aspectual, waste, expiration, visibility, ratios,
# Average loss at step 22000: 0.000019
# Average loss at step 24000: 0.000017
# Average loss at step 26000: 0.000016
# Average loss at step 28000: 0.000015
# Average loss at step 30000: 0.000014
# Nearest to have: motorways, phys, rshavn, critically, moto, wenceslaus, oxford, theatrical,
# Nearest to not: cia, plagioclase, cadres, summarizes, sadly, psychical, understood, explain,
# Nearest to can: montju, limewire, demonstrating, luz, uu, carla, whitespace, asmara,
# Nearest to state: pluto, ack, slobodan, lymphatic, privately, washington, theodora, starships,
# Nearest to that: rovers, samoa, fewest, veritas, outbreaks, messier, recanted, quench,
# Nearest to six: daoud, password, kosova, kinky, pollutant, chrismation, livonian, brutality,
# Nearest to more: startup, quiet, high, manfred, withdraws, zanu, deum, succeed,
# Nearest to the: triphosphate, gator, closures, mcluhan, proof, galatia, wilbur, instructors,
# Nearest to to: clerical, burdensome, reuss, supervisory, multilateral, deer, mats, dod,
# Nearest to three: bessarabia, decca, food, chorus, silky, alkoxide, geometry, ir,
# Nearest to would: dan, sicilian, constituci, succeed, backgammon, helmut, emitter, xyz,
# Nearest to use: lasorda, promise, inquest, wicket, thebes, motif, electrical, coherence,
# Nearest to over: blythe, simulation, astrobiology, private, breathes, steak, psc, location,
# Nearest to some: permutation, calhoun, rebuilding, polymorphic, rakyat, jehovah, flybys, fest,
# Nearest to called: adorned, compactly, pb, dozens, mime, lothal, reconciliation, intercommunal,
# Nearest to all: empiricism, rutland, printed, aspectual, waste, expiration, visibility, ratios,
# Average loss at step 32000: 0.000013
# Average loss at step 34000: 0.000012
# Average loss at step 36000: 0.000011
# Average loss at step 38000: 0.000012
# Average loss at step 40000: 0.000011
# Nearest to have: motorways, phys, rshavn, critically, moto, wenceslaus, oxford, theatrical,
# Nearest to not: cia, plagioclase, cadres, summarizes, sadly, psychical, understood, explain,
# Nearest to can: montju, limewire, demonstrating, luz, uu, carla, whitespace, asmara,
# Nearest to state: pluto, ack, slobodan, lymphatic, privately, washington, theodora, starships,
# Nearest to that: rovers, samoa, veritas, fewest, outbreaks, messier, recanted, quench,
# Nearest to six: daoud, password, kosova, kinky, pollutant, chrismation, livonian, brutality,
# Nearest to more: startup, quiet, high, manfred, withdraws, zanu, deum, succeed,
# Nearest to the: triphosphate, gator, closures, mcluhan, proof, galatia, wilbur, instructors,
# Nearest to to: clerical, burdensome, reuss, supervisory, multilateral, deer, mats, dod,
# Nearest to three: bessarabia, decca, food, chorus, silky, alkoxide, geometry, ir,
# Nearest to would: dan, sicilian, constituci, succeed, backgammon, helmut, emitter, xyz,
# Nearest to use: lasorda, promise, inquest, wicket, thebes, motif, electrical, coherence,
# Nearest to over: blythe, simulation, astrobiology, private, breathes, steak, psc, location,
# Nearest to some: permutation, calhoun, rebuilding, polymorphic, rakyat, jehovah, flybys, fest,
# Nearest to called: adorned, compactly, pb, dozens, mime, lothal, reconciliation, intercommunal,
# Nearest to all: empiricism, rutland, printed, aspectual, waste, expiration, visibility, ratios,
# Average loss at step 42000: 0.000010
# Average loss at step 44000: 0.000009
# Average loss at step 46000: 0.000009
# Average loss at step 48000: 0.000009
# Average loss at step 50000: 0.000009
# Nearest to have: motorways, phys, rshavn, critically, moto, wenceslaus, oxford, theatrical,
# Nearest to not: cia, plagioclase, cadres, summarizes, sadly, psychical, understood, explain,
# Nearest to can: montju, limewire, demonstrating, luz, uu, carla, whitespace, asmara,
# Nearest to state: pluto, ack, slobodan, privately, lymphatic, theodora, washington, starships,
# Nearest to that: rovers, samoa, fewest, veritas, outbreaks, messier, recanted, quench,
# Nearest to six: daoud, password, kosova, kinky, pollutant, chrismation, livonian, brutality,
# Nearest to more: startup, quiet, high, manfred, withdraws, zanu, deum, succeed,
# Nearest to the: triphosphate, gator, closures, mcluhan, proof, galatia, wilbur, instructors,
# Nearest to to: clerical, burdensome, reuss, supervisory, multilateral, deer, mats, dod,
# Nearest to three: bessarabia, decca, food, chorus, silky, alkoxide, geometry, ir,
# Nearest to would: dan, sicilian, constituci, succeed, backgammon, helmut, emitter, xyz,
# Nearest to use: lasorda, promise, inquest, wicket, thebes, motif, electrical, coherence,
# Nearest to over: blythe, simulation, astrobiology, private, breathes, steak, psc, location,
# Nearest to some: permutation, calhoun, rebuilding, polymorphic, rakyat, jehovah, flybys, fest,
# Nearest to called: adorned, compactly, pb, dozens, mime, lothal, reconciliation, intercommunal,
# Nearest to all: empiricism, rutland, printed, aspectual, waste, expiration, visibility, ratios,
# Average loss at step 52000: 0.000008
# Average loss at step 54000: 0.000008
# Average loss at step 56000: 0.000008
# Average loss at step 58000: 0.000007
# Average loss at step 60000: 0.000007
# Nearest to have: motorways, phys, rshavn, critically, moto, wenceslaus, oxford, theatrical,
# Nearest to not: cia, plagioclase, cadres, summarizes, sadly, psychical, understood, explain,
# Nearest to can: montju, limewire, demonstrating, luz, uu, carla, whitespace, asmara,
# Nearest to state: pluto, ack, slobodan, privately, lymphatic, theodora, washington, starships,
# Nearest to that: rovers, samoa, veritas, fewest, outbreaks, messier, recanted, quench,
# Nearest to six: daoud, password, kosova, kinky, pollutant, chrismation, livonian, brutality,
# Nearest to more: startup, quiet, high, manfred, withdraws, zanu, deum, succeed,
# Nearest to the: triphosphate, gator, closures, mcluhan, proof, galatia, wilbur, instructors,
# Nearest to to: clerical, burdensome, reuss, supervisory, multilateral, deer, mats, dod,
# Nearest to three: bessarabia, decca, food, chorus, silky, alkoxide, geometry, ir,
# Nearest to would: dan, sicilian, constituci, succeed, backgammon, helmut, emitter, xyz,
# Nearest to use: lasorda, promise, inquest, wicket, thebes, motif, electrical, coherence,
# Nearest to over: blythe, simulation, astrobiology, private, breathes, steak, psc, location,
# Nearest to some: permutation, calhoun, rebuilding, polymorphic, rakyat, jehovah, flybys, fest,
# Nearest to called: adorned, compactly, pb, dozens, mime, lothal, reconciliation, intercommunal,
# Nearest to all: empiricism, rutland, printed, aspectual, waste, expiration, visibility, ratios,
# Average loss at step 62000: 0.000007
# Average loss at step 64000: 0.000007
# Average loss at step 66000: 0.000006
# Average loss at step 68000: 0.000006
# Average loss at step 70000: 0.000006
# Nearest to have: motorways, phys, rshavn, critically, moto, wenceslaus, oxford, theatrical,
# Nearest to not: cia, plagioclase, cadres, summarizes, sadly, psychical, understood, explain,
# Nearest to can: montju, limewire, demonstrating, luz, uu, carla, whitespace, asmara,
# Nearest to state: pluto, ack, slobodan, privately, lymphatic, theodora, washington, starships,
# Nearest to that: rovers, samoa, veritas, fewest, outbreaks, messier, recanted, quench,
# Nearest to six: daoud, password, kosova, kinky, pollutant, chrismation, livonian, brutality,
# Nearest to more: startup, quiet, high, manfred, withdraws, zanu, deum, succeed,
# Nearest to the: triphosphate, gator, closures, mcluhan, proof, galatia, wilbur, instructors,
# Nearest to to: clerical, burdensome, reuss, supervisory, multilateral, deer, mats, dod,
# Nearest to three: bessarabia, decca, food, chorus, silky, alkoxide, geometry, ir,
# Nearest to would: dan, sicilian, constituci, succeed, backgammon, helmut, emitter, xyz,
# Nearest to use: lasorda, promise, inquest, wicket, thebes, motif, electrical, coherence,
# Nearest to over: blythe, simulation, astrobiology, private, breathes, steak, psc, location,
# Nearest to some: permutation, calhoun, rebuilding, polymorphic, rakyat, jehovah, flybys, fest,
# Nearest to called: adorned, compactly, pb, dozens, mime, lothal, reconciliation, intercommunal,
# Nearest to all: empiricism, rutland, printed, aspectual, waste, expiration, visibility, ratios,
# Average loss at step 72000: 0.000006
# Average loss at step 74000: 0.000006
# Average loss at step 76000: 0.000006
# Average loss at step 78000: 0.000005
# Average loss at step 80000: 0.000005
# Nearest to have: motorways, phys, rshavn, critically, moto, wenceslaus, oxford, theatrical,
# Nearest to not: cia, plagioclase, cadres, summarizes, sadly, psychical, understood, explain,
# Nearest to can: montju, limewire, demonstrating, luz, uu, carla, whitespace, asmara,
# Nearest to state: pluto, ack, slobodan, privately, lymphatic, theodora, washington, starships,
# Nearest to that: rovers, samoa, veritas, fewest, outbreaks, messier, recanted, quench,
# Nearest to six: daoud, password, kosova, kinky, pollutant, chrismation, livonian, brutality,
# Nearest to more: startup, quiet, high, manfred, withdraws, zanu, deum, succeed,
# Nearest to the: triphosphate, gator, closures, mcluhan, proof, galatia, wilbur, instructors,
# Nearest to to: clerical, burdensome, reuss, supervisory, multilateral, deer, mats, dod,
# Nearest to three: bessarabia, decca, food, chorus, silky, alkoxide, geometry, ir,
# Nearest to would: dan, sicilian, constituci, succeed, backgammon, helmut, emitter, xyz,
# Nearest to use: lasorda, promise, inquest, thebes, wicket, motif, electrical, coherence,
# Nearest to over: blythe, simulation, astrobiology, private, breathes, steak, psc, location,
# Nearest to some: permutation, calhoun, rebuilding, polymorphic, rakyat, jehovah, flybys, fest,
# Nearest to called: adorned, compactly, pb, dozens, mime, lothal, reconciliation, intercommunal,
# Nearest to all: empiricism, rutland, printed, aspectual, waste, expiration, visibility, ratios,
# Average loss at step 82000: 0.000005
# Average loss at step 84000: 0.000005
# Average loss at step 86000: 0.000005
# Average loss at step 88000: 0.000005
# Average loss at step 90000: 0.000005
# Nearest to have: motorways, phys, rshavn, critically, moto, wenceslaus, oxford, theatrical,
# Nearest to not: cia, plagioclase, cadres, summarizes, sadly, psychical, understood, explain,
# Nearest to can: montju, limewire, demonstrating, luz, uu, carla, whitespace, asmara,
# Nearest to state: pluto, ack, slobodan, privately, lymphatic, theodora, washington, starships,
# Nearest to that: rovers, samoa, veritas, fewest, outbreaks, messier, recanted, quench,
# Nearest to six: daoud, password, kosova, kinky, pollutant, chrismation, livonian, brutality,
# Nearest to more: startup, quiet, high, manfred, withdraws, zanu, deum, succeed,
# Nearest to the: triphosphate, gator, closures, mcluhan, proof, galatia, wilbur, instructors,
# Nearest to to: clerical, burdensome, reuss, supervisory, multilateral, deer, mats, dod,
# Nearest to three: bessarabia, decca, food, chorus, silky, alkoxide, geometry, ir,
# Nearest to would: dan, sicilian, constituci, succeed, backgammon, helmut, emitter, xyz,
# Nearest to use: lasorda, promise, inquest, thebes, wicket, motif, electrical, coherence,
# Nearest to over: blythe, simulation, astrobiology, private, breathes, steak, psc, location,
# Nearest to some: permutation, calhoun, rebuilding, polymorphic, rakyat, jehovah, flybys, fest,
# Nearest to called: adorned, compactly, pb, dozens, mime, lothal, reconciliation, intercommunal,
# Nearest to all: empiricism, rutland, printed, aspectual, waste, expiration, visibility, ratios,
# Average loss at step 92000: 0.000005
# Average loss at step 94000: 0.000005
# Average loss at step 96000: 0.000005
# Average loss at step 98000: 0.000004
# Average loss at step 100000: 0.000004
# Nearest to have: motorways, phys, rshavn, critically, moto, wenceslaus, oxford, theatrical,
# Nearest to not: cia, plagioclase, cadres, summarizes, sadly, psychical, understood, explain,
# Nearest to can: montju, limewire, demonstrating, luz, uu, carla, whitespace, asmara,
# Nearest to state: pluto, ack, slobodan, privately, lymphatic, theodora, washington, starships,
# Nearest to that: rovers, samoa, veritas, fewest, outbreaks, messier, recanted, quench,
# Nearest to six: daoud, password, kosova, kinky, pollutant, chrismation, livonian, brutality,
# Nearest to more: startup, quiet, high, manfred, withdraws, zanu, deum, succeed,
# Nearest to the: triphosphate, gator, closures, mcluhan, proof, galatia, wilbur, instructors,
# Nearest to to: clerical, burdensome, reuss, supervisory, multilateral, deer, mats, dod,
# Nearest to three: bessarabia, decca, food, chorus, silky, alkoxide, geometry, ir,
# Nearest to would: dan, sicilian, constituci, succeed, backgammon, helmut, emitter, xyz,
# Nearest to use: lasorda, promise, inquest, thebes, wicket, motif, electrical, coherence,
# Nearest to over: blythe, simulation, astrobiology, private, breathes, steak, psc, location,
# Nearest to some: permutation, calhoun, rebuilding, polymorphic, rakyat, jehovah, flybys, fest,
# Nearest to called: adorned, compactly, pb, dozens, mime, lothal, reconciliation, intercommunal,
# Nearest to all: empiricism, rutland, printed, aspectual, waste, expiration, visibility, ratios,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
